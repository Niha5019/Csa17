# %%
subjects = ["DBMS", "AI", "DS"]

for stateA in subjects:
    for stateB in subjects:

        # Constraint: Adjacent states cannot have same color
        if stateA != stateB:
            print("State A =", stateA,
                  "State B =", stateB)
# Out:
# State A = DBMS State B = AI
# State A = DBMS State B = DS
# State A = AI State B = DBMS
# State A = AI State B = DS
# State A = DS State B = DBMS
# State A = DS State B = AI
